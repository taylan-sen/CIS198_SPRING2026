# %% [markdown]
# <a href="https://colab.research.google.com/github/taylan-sen/CIS198_SPRING2026/blob/main/ShellCommands_ProgramModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Shell Commands
#
# Regarding computer systems, what is a **shell**? (Type a short answer below in a new text cell.)

# %% [markdown]
# For each of the following shell commands, give a short description of what they do after the hash mark:
#
#     pwd  #
#     ls #
#     cd #
#     mkdir #
#     echo "hello" #
#     echo "hello" > hello.txt #
#     cat hello.txt
#     mv hello.txt h.txt  #
#     history  #
#     sudo apt update  #
#     sudo apt upgrade  #
#     sudo apt install micro  #
#     micro hello.py  #
#     python3 hello.py  #
#     ping #
#     gcc main.c #
#     sudo apt install micro #
#     sudo apt install build-essential #

# %% [markdown]
# In the cell below, enter the magic command to install ping (then execute the cell).

# %% [markdown]
# In the cell below, run the magic comand to ping your Google Cloud VM. (Press stop button after a few pings)

# %% [markdown]
# ## Program Model
#
# ### C code
#
# main.c
#   ↓ (preprocessor)
# expanded source
#   ↓ (compiler)
# assembly code
#   ↓ (assembler)
# object file (.o)
#   ↓ (linker)
# executable
#
#
# C:
# source code:
# machine code:
# assembly code:
# object file:
# executable:
#
# preprocessor:
# compiler:
# linker:

# %%
// main.c
#include <stdio.h>

int main() {
    printf("Hello, world!\n");
    return 0;
}

# %% [markdown]
# ### python model
#
# hello.py
#   ↓ ("compiler")
# BYTECODE (hello.pyc)
#   ↓ (Python Virtual Machine:interpreter, line by line)
# MACHINE CODE
