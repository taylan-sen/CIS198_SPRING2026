# %% [markdown]
# <a href="https://colab.research.google.com/github/taylan-sen/CIS198_SPRING2026/blob/main/cis198_Creating_a_Github_Website_w_Markdown%2C_HTML%2C_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook we will have notes on Markdown, HTML, and creating a website on github.com

# %% [markdown]
# * Google search (or another search provider)
#   * SEARCH: "How to create a website hosted on github.com"
# * Ask a LLM (large language model i.e. chatgpt)
#   * PROMPT: "How to create a website hosted on github.com"

# %% [markdown]
# ### github notes
#
# key terms:
# * **repository** - a container holding all *committed* files and folders.
# * **commit** - saving a file version in a repository (along with a save message, i.e. commit message)
# * **git** - version control program (i.e. a app for saving many versions of files, ex. computer code.
# * **github.com** - a online company (website) providing a place for users to save their repositories.
